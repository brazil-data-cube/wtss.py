# %% [markdown]
# # WTSS Python Client - Notebook example

# %% [markdown]
# ## 1) Connect to WTSS server

# %%
#
# This file is part of Python Client Library for WTSS.
# Copyright (C) 2022 INPE.
#
# Python Client Library for WTSS is free software; you can redistribute it and/or modify it
# under the terms of the MIT License; see LICENSE file for more details.
#

from wtss import *

SERVER_URL = 'http://127.0.0.1:6000/'
BDC_AUTH_TOKEN = 'change-me'

service = WTSS(url=SERVER_URL, access_token=BDC_AUTH_TOKEN)

# %% [markdown]
# ## 2) Print all available coverages and select MOD13Q1-6

# %%
print('\n\t CUBES:', service.cubes)
print('\n\t COLLECTIONS:', service.collections)
print('\n\t MOSAICS:', service.mosaics)
print('\n\t CLASSIFICATIONS:', service.classifications)

coverage = service['MOD13Q1-6']
coverage
# Out:
# 	 CUBES: ['MOD13Q1-6', 'MYD13Q1-6', 'S2-SEN2COR_10_16D_STK-1', 'LC8_30_16D_STK-1', 'CB4MUX_20_1M_STK-1', 'LC8_30_6M_MEDSTK-1', 'CB4_64_16D_STK-1', 'LANDSAT-MOZ_30_1M_STK-1']
#
# 	 COLLECTIONS: ['S2_L1C-1', 'S2_L2A-1', 'LC8_DN-1', 'LC8_SR-1']
#
# 	 MOSAICS: ['LCC_S2_10_16D_STK_Amazonia-1', 'LCC_L8_30_1M_STK_Cerrado-1', 'LCC_L8_30_16D_STK_Amazonia-TC-1', 'LCC_L8_30_16D_STK_Pantanal-1', 'LCC_L8_30_1M_STK_PA-SPC-AC-NA-1', 'LCC_S2_10_1M_STK_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_MT_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_GO_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_MT_RF_PA-SPC-AC-NA-1', 'KD_S2_20M_VISBANDS_CURUAI-1']
#
# 	 CLASSIFICATIONS: ['LCC_S2_10_16D_STK_Amazonia-1', 'LCC_L8_30_1M_STK_Cerrado-1', 'LCC_L8_30_16D_STK_Amazonia-TC-1', 'LCC_L8_30_16D_STK_Pantanal-1', 'LCC_L8_30_1M_STK_PA-SPC-AC-NA-1', 'LCC_S2_10_1M_STK_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_MT_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_GO_PA-SPC-AC-NA-1', 'LCC_C4_64_1M_STK_MT_RF_PA-SPC-AC-NA-1', 'KD_S2_20M_VISBANDS_CURUAI-1']
# <div>
#     <div>
#         <b>Coverage Name:</b> MOD13Q1-6
#     </div>
#     <br/>
#     <div>
#         <b>Description:</b> The Terra Moderate Resolution Imaging Spectroradiometer (MODIS) Vegetation Indices (MOD13Q1) Version 6 data are generated every 16 days at 250 meter (m) spatial resolution as a Level 3 product. The MOD13Q1 product provides two primary vegetation layers. The first is the Normalized Difference Vegetation Index (NDVI) which is referred to as the continuity index to the existing National Oceanic and Atmospheric Administration-Advanced Very High Resolution Radiometer (NOAA-AVHRR) derived NDVI. The second vegetation layer is the Enhanced Vegetation Index (EVI), which has improved sensitivity over high biomass regions. The algorithm chooses the best available pixel value from all the acquisitions from the 16 day period. The criteria used is low clouds, low view angle, and the highest NDVI/EVI value.
#     </div>
#     <br/>
#     <div>
#         <b>Attributes:</b>
#     </div>
#     <div>
#         <table>
#             <tr>
#             </tr>
#             <tr>
#                 <th>name</th>
#                 <th>common name</th>
#                 <th>description</th>
#                 <th>min</th>
#                 <th>max</th>
#                 <th>nodata</th>
#                 <th>scale</th>
#                 <th>center_wavelength</th>
#                 <th>full_width_half_max</th>
#                 <th>data_type</th>
#             </tr>
#             <tr>
#                 <td>relative_azimuth_angle</td>
#                 <td></td>
#                 <td>Relative azimuth angle of VI pixel</td>
#                 <td>-18000.0</td>
#                 <td>18000.0</td>
#                 <td>-10000.0</td>
#                 <td>0.01</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>composite_day_of_the_year</td>
#                 <td>quality</td>
#                 <td>Day of year VI pixel</td>
#                 <td>1.0</td>
#                 <td>366.0</td>
#                 <td>-1.0</td>
#                 <td>1.0</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>view_zenith_angle</td>
#                 <td></td>
#                 <td>View zenith angle of VI Pixel</td>
#                 <td>0.0</td>
#                 <td>18000.0</td>
#                 <td>-10000.0</td>
#                 <td>0.01</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>sun_zenith_angle</td>
#                 <td></td>
#                 <td>Sun zenith angle of VI pixel</td>
#                 <td>0.0</td>
#                 <td>18000.0</td>
#                 <td>-10000.0</td>
#                 <td>0.01</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>pixel_reliability</td>
#                 <td>quality</td>
#                 <td>Quality reliability of VI pixel</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td>-1.0</td>
#                 <td>1.0</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>blue_reflectance</td>
#                 <td>blue</td>
#                 <td>Surface Reflectance Band 3</td>
#                 <td>0.0</td>
#                 <td>10000.0</td>
#                 <td>-1000.0</td>
#                 <td>0.0001</td>
#                 <td>0.469</td>
#                 <td>0.01</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>red_reflectance</td>
#                 <td>red</td>
#                 <td>Surface Reflectance Band 1</td>
#                 <td>0.0</td>
#                 <td>10000.0</td>
#                 <td>-1000.0</td>
#                 <td>0.0001</td>
#                 <td>0.645</td>
#                 <td>0.025</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>NIR_reflectance</td>
#                 <td>nir</td>
#                 <td>Surface Reflectance Band 2</td>
#                 <td>0.0</td>
#                 <td>10000.0</td>
#                 <td>-1000.0</td>
#                 <td>0.0001</td>
#                 <td>0.8585</td>
#                 <td>0.175</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>MIR_reflectance</td>
#                 <td>swir22</td>
#                 <td>Surface Reflectance Band 7</td>
#                 <td>0.0</td>
#                 <td>10000.0</td>
#                 <td>-1000.0</td>
#                 <td>0.0001</td>
#                 <td>0.213</td>
#                 <td>0.0025</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>VI_Quality</td>
#                 <td>quality</td>
#                 <td>VI quality indicators</td>
#                 <td>0.0</td>
#                 <td>65534.0</td>
#                 <td>65535.0</td>
#                 <td>1.0</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>uint16</td>
#             </tr><tr>
#                 <td>NDVI</td>
#                 <td>ndvi</td>
#                 <td>16 day NDVI</td>
#                 <td>-2000.0</td>
#                 <td>10000.0</td>
#                 <td>-3000.0</td>
#                 <td>0.0001</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr><tr>
#                 <td>EVI</td>
#                 <td>evi</td>
#                 <td>16 day EVI</td>
#                 <td>-2000.0</td>
#                 <td>10000.0</td>
#                 <td>-3000.0</td>
#                 <td>0.0001</td>
#                 <td>None</td>
#                 <td>None</td>
#                 <td>int16</td>
#             </tr>
#         </table>
#     </div>
#     </br>
#     <div>
#         <b>Extent</b>
#     </div>
#     <div>
#         <table>
#             <tr>
#                 <th>xmin</th>
#                 <th>ymin</th>
#                 <th>xmax</th>
#                 <th>ymax</th>
#             </tr>
#              <tr>
#                  <td>-81.234129</td>
#                  <td>-40.0</td>
#                  <td>-21.283555</td>
#                  <td>10.0</td>
#              </tr>
#         </table>
#     </div>
#     <br/>
#     <div>
#         <b>Timeline</b>
#     </div>
#         <select id="timeline" size="10">
#         <option value="{d}">2000-02-18</option><option value="{d}">2000-03-05</option><option value="{d}">2000-03-21</option><option value="{d}">2000-04-06</option><option value="{d}">2000-04-22</option><option value="{d}">2000-05-08</option><option value="{d}">2000-05-24</option><option value="{d}">2000-06-09</option><option value="{d}">2000-06-25</option><option value="{d}">2000-07-11</option><option value="{d}">2000-07-27</option><option value="{d}">2000-08-12</option><option value="{d}">2000-08-28</option><option value="{d}">2000-09-13</option><option value="{d}">2000-09-29</option><option value="{d}">2000-10-15</option><option value="{d}">2000-10-31</option><option value="{d}">2000-11-16</option><option value="{d}">2000-12-02</option><option value="{d}">2000-12-18</option><option value="{d}">2001-01-01</option><option value="{d}">2001-01-17</option><option value="{d}">2001-02-02</option><option value="{d}">2001-02-18</option><option value="{d}">2001-03-06</option><option value="{d}">2001-03-22</option><option value="{d}">2001-04-07</option><option value="{d}">2001-04-23</option><option value="{d}">2001-05-09</option><option value="{d}">2001-05-25</option><option value="{d}">2001-06-10</option><option value="{d}">2001-06-26</option><option value="{d}">2001-07-12</option><option value="{d}">2001-07-28</option><option value="{d}">2001-08-13</option><option value="{d}">2001-08-29</option><option value="{d}">2001-09-14</option><option value="{d}">2001-09-30</option><option value="{d}">2001-10-16</option><option value="{d}">2001-11-01</option><option value="{d}">2001-11-17</option><option value="{d}">2001-12-03</option><option value="{d}">2001-12

# %% [markdown]
# _______________________________________
# ## 3) Timeseries: The user can retrieve all timeseries inside the geometry

# %%
# Set the query parameters
attributes = ['NDVI','EVI']
geometry = {"type":"Polygon","coordinates":[[[-54,-12],[-53.99,-12],[-53.99,-11.99],[-54,-11.99],[-54,-12]]]}
start_datetime = '2017-01-01'
end_datetime = '2018-01-31'

# Retrieve data
timeseries = coverage.ts(
    attributes = attributes,
    geom = geometry,
    start_datetime = start_datetime,
    end_datetime = end_datetime
)

timeseries
# Out:
# <div>
#     <div>
#         <b>Time Series</b> MOD13Q1-6
#     </div>
#     <br/>
#     <div>
#         <div>
#             <b>NDVI:</b> [[0.8598, None, 0.8317, 0.8410000000000001, 0.8714000000000001, 0.6047, 0.883, 0.8636, 0.8432000000000001, 0.8726, 0.8783000000000001, 0.8791, 0.8609, 0.8646, 0.8759, 0.8625, 0.8430000000000001, 0.8709, 0.8981, 0.8824000000000001, 0.6465000000000001, 0.5303, 0.8206, 0.8706, 0.892], [0.8679, 0.5545, 0.8315, 0.8410000000000001, 0.8792000000000001, 0.9916, 0.883, 0.8781, 0.8516, 0.8817, 0.8806, 0.8807, 0.8644000000000001, 0.8654000000000001, 0.871, 0.8672000000000001, 0.8430000000000001, 0.8777, 0.8976000000000001, 0.8875000000000001, 0.6465000000000001, 0.5252, 0.8226, 0.8724000000000001, 0.892], [0.8719, 0.5545, 0.8523000000000001, 0.8427, 0.8862, 0.9494, 0.8861, 0.8742000000000001, 0.8577, 0.883, 0.8827, 0.8728, 0.8692000000000001, 0.863, 0.8716, 0.8696, 0.8413, 0.8849, 0.9014000000000001, 0.9238000000000001, 0.6514, 0.5252, 0.8320000000000001, 0.8581000000000001, 0.8946000000000001], [0.8719, 0.6603, 0.8510000000000001, 0.8427, 0.8654000000000001, 0.6838000000000001, 0.8871, 0.8775000000000001, 0.8646, 0.8969, 0.8827, 0.8791, 0.8617, 0.8653000000000001, 0.8706, 0.8658, 0.8406, 0.8849, 0.9014000000000001, 0.894, 0.5937, 0.38130000000000003, 0.8389000000000001, 0.8841, 0.8908], [0.8694000000000001, 0.8644000000000001, 0.8510000000000001, 0.8627, 0.8592000000000001, 0.5177, 0.8826, 0.879, 0.8560000000000001, 0.8958, 0.8887, 0.8667, 0.8591000000000001, 0.8649, 0.8687, 0.8547, 0.8308000000000001, 0.884, 0.8999, 0.8873000000000001, 0.8048000000000001, 0.38870000000000005, 0.8453, 0.8841, 0.8908], [0.8841, 0.8644000000000001, 0.8448, 0.8304, 0.8592000000000001, 0.4671, 0.8683000000000001, 0.8818, 0.8528, 0.8932, 0.8821, 0.8692000000000001, 0.8586, 0.862, 0.8570000000000001, 0.8604, 0.8356, 0.8822000000000001, 0.8977, 0.8873000000000001, 0.6464000000000001, 0.3604, 0.20700000000000002, 0.8776, 0.8852000000000001], [0.8498, 0.7132000000000001, 0.8232, 0.8410000000000001, 0.8611000000000001, 0.6047, 0.8666, 0.8636, 0.8357, 0.86, 0.8558, 0.8418, 0.8550000000000001, 0.8626, 0.8751, 0.8674000000000001, 0.8411000000000001, 0.8669, 0.8948, 0.9811000000000001, 0.5832, 0.5303, 0.7739, 0.8542000000000001, 0.8634000000000001], [0.8742000000000001, 0.5545, 0.8315, 0.8410000000000001, 0.8612000000000001, 0.9916, 0.8612000000000001, 0.8703000000000001, 0.8389000000000001, 0.8724000000000001, 0.8558, 0.8560000000000001, 0.8485, 0.8555, 0.8667, 0.8637, 0.8421000000000001, 0.8801, 0.8948, 0.8686, 0.5832, 0.5252, 0.8718, 0.8518, 0.8651000000000001], [0.8833000000000001, 0.5545, 0.8523000000000001, 0.8427, 0.8795000000000001, 0.9916, 0.873, 0.8756, 0.8574, 0.8788, 0.8772000000000001, 0.8674000000000001, 0.8704000000000001, 0.8585, 0.8704000000000001, 0.8646, 0.8323, 0.8801, 0.8948, 0.8686, 0.5315, 0.5252, 0.8985000000000001, 0.8754000000000001, 0.8801], [0.8833000000000001, 0.617, 0.8510000000000001, 0.8427, 0.8613000000000001, 0.5517000000000001, 0.8695, 0.8848, 0.8631000000000001, 0.8844000000000001, 0.8702000000000001, 0.8603000000000001, 0.8606, 0.86, 0.8671000000000001, 0.8609, 0.8407, 0.8689, 0.8981, 0.9238000000000001, 0.7533000000000001, 0.6061000000000001, 0.7965, 0.8754000000000001, 0.8795000000000001], [0.8841, 0.5021, 0.8510000000000001, 0.8627, 0.8624, 0.5688, 0.8809, 0.879, 0.8639, 0.8851, 0.8823000000000001, 0.8686, 0.8673000000000001, 0.8649, 0.8653000000000001, 0.8631000000000001, 0.8391000000000001, 0.8777, 0.8953000000000001, 0.9254, 0.7666000000000001, 0.5083, 0.8077000000000001, 0.8668, 0.8828], [0.8841, 0.5583, 0.8448, 0.8304, 0.8624, 0.5489, 0.8809, 0.8818, 0.8615, 0.8851, 0.8698, 0.8689, 0.8574, 0.862, 0.8712000000000001, 0.8618, 0.8391000000000001, 0.8848, 0.8976000000000001, 0.8891, 0.4842, 0.5713, 0.8184, 0.8668, 0.8832000000000001], [0.8338, 0.7132000000000001, 0.8187000000000001, 0.8410000000000001, 0.8517, 0.7555000000000001, 0.8597, 0.8591000000000001, 0.8405, 0.8665, 0.8645, 0.8544, 0.8608, 0.8613000000000001, 0.8711000000000001, 0.8608, 0.8468, 0.8749, 0.8975000000000001, 0.9108, 0.6959000000000 ...

# %% [markdown]
# ### 3.1) The query results are available as timeseries properties:

# %%
print('\n\t time-series attributes:', timeseries.attributes)

print('\n\t time-series number of pixels:', timeseries.number_of_pixels)

print('\n\t time-series timeline:', timeseries.timeline)

print('\n\t NDVI time-series from pixel 1:', timeseries.NDVI[0])

print('\n\t EVI time-series from pixel 1:', timeseries.EVI[0])
# Out:
# 	 time-series attributes: ['NDVI', 'EVI']
#
# 	 time-series number of pixels: 42
#
# 	 time-series timeline: ['2017-01-01T00:00:00Z', '2017-01-17T00:00:00Z', '2017-02-02T00:00:00Z', '2017-02-18T00:00:00Z', '2017-03-06T00:00:00Z', '2017-03-22T00:00:00Z', '2017-04-07T00:00:00Z', '2017-04-23T00:00:00Z', '2017-05-09T00:00:00Z', '2017-05-25T00:00:00Z', '2017-06-10T00:00:00Z', '2017-06-26T00:00:00Z', '2017-07-12T00:00:00Z', '2017-07-28T00:00:00Z', '2017-08-13T00:00:00Z', '2017-08-29T00:00:00Z', '2017-09-14T00:00:00Z', '2017-09-30T00:00:00Z', '2017-10-16T00:00:00Z', '2017-11-01T00:00:00Z', '2017-11-17T00:00:00Z', '2017-12-03T00:00:00Z', '2017-12-19T00:00:00Z', '2018-01-01T00:00:00Z', '2018-01-17T00:00:00Z']
#
# 	 NDVI time-series from pixel 1: [0.8598, None, 0.8317, 0.8410000000000001, 0.8714000000000001, 0.6047, 0.883, 0.8636, 0.8432000000000001, 0.8726, 0.8783000000000001, 0.8791, 0.8609, 0.8646, 0.8759, 0.8625, 0.8430000000000001, 0.8709, 0.8981, 0.8824000000000001, 0.6465000000000001, 0.5303, 0.8206, 0.8706, 0.892]
#
# 	 EVI time-series from pixel 1: [0.6396000000000001, None, 0.6716000000000001, 0.5760000000000001, 0.4995, 0.4048, 0.4439, 0.4005, 0.4521, 0.48750000000000004, 0.48260000000000003, 0.4703, 0.4728, 0.496, 0.48460000000000003, 0.5296000000000001, 0.5867, 0.4807, 0.5255000000000001, 0.4748, 0.3703, 0.3039, 0.5601, 0.40390000000000004, 0.47900000000000004]

# %% [markdown]
# ### 3.2) All values from each datetime and each attribute are available in a pandas dataframe format

# %%
timeseries_df = timeseries.pandas_dataframe()
timeseries_df
# Out:
#      attribute   datetime   value
# 0         NDVI 2017-01-01  0.8598
# 1         NDVI 2017-01-17     NaN
# 2         NDVI 2017-02-02  0.8317
# 3         NDVI 2017-02-18  0.8410
# 4         NDVI 2017-03-06  0.8714
# ...        ...        ...     ...
# 2095       EVI 2017-11-17  0.3372
# 2096       EVI 2017-12-03  0.3271
# 2097       EVI 2017-12-19  0.6342
# 2098       EVI 2018-01-01  0.3635
# 2099       EVI 2018-01-17  0.3884
#
# [2100 rows x 3 columns]

# %% [markdown]
# ### 3.3) The user can plot the time series for each pixel

# %%
timeseries.plot(attribute='NDVI')

# %% [markdown]
# _______________________________________
# ## 4) Summarize: The user can retrieve summarized timeseries from a geometry (e.g. mean, median, min, max, std)

# %%
# Set the query parameters
attributes = ['NDVI','EVI']
geometry = {"type":"Polygon","coordinates":[[[-54,-12],[-53.99,-12],[-53.99,-11.99],[-54,-11.99],[-54,-12]]]}
start_datetime = '2017-01-01'
end_datetime = '2018-01-31'
aggregations = ['mean', 'std']

# Retrieve data
summarize = coverage.summarize(
    attributes = attributes,
    geom = geometry,
    start_datetime = start_datetime,
    end_datetime = end_datetime,
    aggregations = aggregations
)
summarize
# Out:
# <div>
#     <div>
#         <b>Time Series</b> MOD13Q1-6
#     </div>
#
#     <br/>
#
#     <div>
#         <b>Summarize:</b>
#     </div>
#     <div>
#         <div>
#             <b>NDVI</b>
#         </div>
#         <table>
#             <tr>
#             </tr>
#             <tr>
#                 <th>datetime</th>
#                 <th>mean</th><th>std</th>
#             </tr>
#
#
#                 <tr>
#                     <td>2017-01-01T00:00:00Z</td>
#                     <td>0.8632119047619048</td><td>0.01695433927292379</td>
#                 </tr>
#                 <tr>
#                     <td>2017-01-17T00:00:00Z</td>
#                     <td>0.6067829268292684</td><td>0.16496400184170118</td>
#                 </tr>
#                 <tr>
#                     <td>2017-02-02T00:00:00Z</td>
#                     <td>0.8280547619047619</td><td>0.016372584552944307</td>
#                 </tr>
#                 <tr>
#                     <td>2017-02-18T00:00:00Z</td>
#                     <td>0.8384261904761905</td><td>0.013299463997860424</td>
#                 </tr>
#                 <tr>
#                     <td>2017-03-06T00:00:00Z</td>
#                     <td>0.8498857142857146</td><td>0.016026192421701887</td>
#                 </tr>
#                 <tr>
#                     <td>2017-03-22T00:00:00Z</td>
#                     <td>0.4995238095238094</td><td>0.28959785730719095</td>
#                 </tr>
#                 <tr>
#                     <td>2017-04-07T00:00:00Z</td>
#                     <td>0.869347619047619</td><td>0.011036956061023817</td>
#                 </tr>
#                 <tr>
#                     <td>2017-04-23T00:00:00Z</td>
#                     <td>0.8640214285714285</td><td>0.014656715277342608</td>
#                 </tr>
#                 <tr>
#                     <td>2017-05-09T00:00:00Z</td>
#                     <td>0.8420857142857143</td><td>0.01527169138710998</td>
#                 </tr>
#                 <tr>
#                     <td>2017-05-25T00:00:00Z</td>
#                     <td>0.8633976190476191</td><td>0.032661652832635966</td>
#                 </tr>
#                 <tr>
#                     <td>2017-06-10T00:00:00Z</td>
#                     <td>0.8665047619047619</td><td>0.015799592405546608</td>
#                 </tr>
#                 <tr>
#                     <td>2017-06-26T00:00:00Z</td>
#                     <td>0.8641785714285717</td><td>0.012989071151847428</td>
#                 </tr>
#                 <tr>
#                     <td>2017-07-12T00:00:00Z</td>
#                     <td>0.8659404761904765</td><td>0.011924964999924877</td>
#                 </tr>
#                 <tr>
#                     <td>2017-07-28T00:00:00Z</td>
#                     <td>0.8658904761904761</td><td>0.00977359926692237</td>
#                 </tr>
#                 <tr>
#                     <td>2017-08-13T00:00:00Z</td>
#                     <td>0.8730357142857146</td><td>0.008343541027090853</td>
#                 </tr>
#                 <tr>
#                     <td>2017-08-29T00:00:00Z</td>
#                     <td>0.8640023809523809</td><td>0.009855950295929236</td>
#                 </tr>
#                 <tr>
#                     <td>2017-09-14T00:00:00Z</td>
#                     <td>0.8388690476190478</td><td>0.0058631816527351804</td>
#                 </tr>
#                 <tr>
#                     <td>2017-09-30T00:00:00Z</td>
#                     <td>0.8704738095238095</td><td>0.00918098603283696</td>
#                 </tr>
#                 <tr>
#                     <td>2017-10-16T00:00:00Z</td>
#                     <td>0.8921404761904759</td><td>0.007879692389566683</td>
#                 </tr>
#                 <tr>
#                     <td>2017-11-01T00:00:00Z</td>
#                     <td>0.8944952380952377</td><td>0.03281875155326205</td>
#                 </tr>
#                 <tr>
#                     <td>2017-11-17T00:00:00Z</td>
#                     <td>0.6704476190476192</td><td>0.09200628922109526</td>
#                 </tr>
#                 <tr>
#                     <td>2017-12-03T00:00:00Z</td>
#                     <td>0.4670761904761904</td><td>0.08393443816037047</td>
#                 </tr>
#                 <tr>
#                     <td>2017-12-19T00:00:00Z</td>
#                     <td>0.8091690476190477</td><td>0.09994197956837433</td>
#                 </tr>
#                 <tr>
#                     <td>2018-01-01T00:00:00Z</td>
#                     <td>0.8648095238095239</td><td>0.011214930726572234</td>
#                 </tr>
#                 <tr>
#                     <td>2018-01-17T00:00:00Z</td>
#                     <td>0.8741809523809526</td><td>0.011229939534570679</td>
#                 </tr>
#         </table>
#     </div>
#     <br/><div>
#         <div>
#             <b>EVI</b>
#         </div>
#         <table>
#             <tr>
#             </tr>
#             <tr>
#                 <th>datetime</th>
#                 <th>mean</th><th>std</th>
#             </tr>
#
#
#                 <tr>
#                     <td>2017-01-01T00:00:00Z</td>
#                     <td>0.5245071428571426</td><td>0.10599100679023747</td>
#                 </tr>
#                 <tr>
#                     <td>2017-01-17T00:00:00Z</td>
#                     <td>0.38219268292682923</td><td>0.08828270385595913</td>
#                 </tr>
#                 <tr>
#                     <td>2017-02-02T00:00:00Z</td>
#                     <td>0.6582976190476191</td><td>0.036864361988338486</td>
#                 </tr>
#                 <tr>
#                     <td>2017-02-18T00:00:00Z</td>
#                     <td>0.5762190476190474</td><td>0.02562662527338501</td>
#                 </tr>
#                 <tr>
#                     <td>2017-03-06T00:00:00Z</td>
#                     <td>0.5724023809523809</td><td>0.05753659079268905</td>
#                 </tr>
#                 <tr>
#                     <td>2017-03-22T00:00:00Z</td>
#                     <td>0.3181809523809524</td><td>0.10706810524613637</td>
#                 </tr>
#                 <tr>
#                     <td>2017-04-07T00:00:00Z</td>
#                     <td>0.405895238095238</td><td>0.029269706039008615</td>
#                 </tr>
#                 <tr>
#                     <td>2017-04-23T00:00:00Z</td>
#                     <td>0.4171095238095239</td><td>0.03464851271132104</td>
#                 </tr>
#                 <tr>
#                     <td>2017-05-09T00:00:00Z</td>
#                     <td>0.4507690476190477</td><td>0.030571940824220458</td>
#                 </tr>
#                 <tr>
#                     <td>2017-05-25T00:00:00Z</td>
#                     <td>0.46800952380952376</td><td>0.03778402792768274</td>
#                 </tr>
#                 <tr>
#                     <td>2017-06-10T00:00:00Z</td>
#                     <td>0.4563880952380953</td><td>0.03212559580608105</td>
#                 </tr>
#                 <tr>
#                     <td>2017-06-26T00:00:00Z</td>
#                     <td>0.4052261904761905</td><td>0.05229648563046137</td>
#                 </tr>
#                 <tr>
#                     <td>2017-07-12T00:00:00Z</td>
#                     <td>0.479504761904762</td><td>0.02434185062007359</td>
#                 </tr>
#                 <tr>
#                     <td>2017-07-28T00:00:00Z</td>
#                     <td>0.489354761904762</td><td>0.021654046167391007</td>
#                 </tr>
#                 <tr>
#                     <td>2017-08-13T00:00:00Z</td>
#                     <td>0.47720714285714294</td><td>0.0164146333213639</td>
#                 </tr>
#                 <tr>
#                     <td>2017-08-29T00:00:00Z</td>
#                     <td>0.5324309523809523</td><td>0.017109611446636516</td>
#                 </tr>
#                 <tr>
#                     <td>2017-09-14T00:00:00Z</td>
#                     <td>0.575702380952381</td><td>0.017577088551580827</td>
#                 </tr>
#                 <tr>
#                     <td>2017-09-30T00:00:00Z</td>
#                     <td>0.4984476190476189</td><td>0.060835285962511816</td>
#                 </tr>
#                 <tr>
#                     <td>2017-10-16T00:00:00Z</td>

# %% [markdown]
# ### 4.1) The query results are available as timeseries properties:

# %%
print('\n\t summarize attributes:', summarize.attributes)

print('\n\t summarize timeline:', summarize.timeline)

print('\n\t NDVI mean:', summarize.NDVI.mean)

print('\n\t EVI std:', summarize.EVI.std)
# Out:
# 	 summarize attributes: ['NDVI', 'EVI']
#
# 	 summarize timeline: ['2017-01-01T00:00:00Z', '2017-01-17T00:00:00Z', '2017-02-02T00:00:00Z', '2017-02-18T00:00:00Z', '2017-03-06T00:00:00Z', '2017-03-22T00:00:00Z', '2017-04-07T00:00:00Z', '2017-04-23T00:00:00Z', '2017-05-09T00:00:00Z', '2017-05-25T00:00:00Z', '2017-06-10T00:00:00Z', '2017-06-26T00:00:00Z', '2017-07-12T00:00:00Z', '2017-07-28T00:00:00Z', '2017-08-13T00:00:00Z', '2017-08-29T00:00:00Z', '2017-09-14T00:00:00Z', '2017-09-30T00:00:00Z', '2017-10-16T00:00:00Z', '2017-11-01T00:00:00Z', '2017-11-17T00:00:00Z', '2017-12-03T00:00:00Z', '2017-12-19T00:00:00Z', '2018-01-01T00:00:00Z', '2018-01-17T00:00:00Z']
#
# 	 NDVI mean: [0.8632119047619048, 0.6067829268292684, 0.8280547619047619, 0.8384261904761905, 0.8498857142857146, 0.4995238095238094, 0.869347619047619, 0.8640214285714285, 0.8420857142857143, 0.8633976190476191, 0.8665047619047619, 0.8641785714285717, 0.8659404761904765, 0.8658904761904761, 0.8730357142857146, 0.8640023809523809, 0.8388690476190478, 0.8704738095238095, 0.8921404761904759, 0.8944952380952377, 0.6704476190476192, 0.4670761904761904, 0.8091690476190477, 0.8648095238095239, 0.8741809523809526]
#
# 	 EVI std: [0.10599100679023747, 0.08828270385595913, 0.036864361988338486, 0.02562662527338501, 0.05753659079268905, 0.10706810524613637, 0.029269706039008615, 0.03464851271132104, 0.030571940824220458, 0.03778402792768274, 0.03212559580608105, 0.05229648563046137, 0.02434185062007359, 0.021654046167391007, 0.0164146333213639, 0.017109611446636516, 0.017577088551580827, 0.060835285962511816, 0.02376198504137598, 0.05282736548624856, 0.09692446871690566, 0.05270553719291409, 0.11473337444215764, 0.025366294346807716, 0.03202041865566961]

# %% [markdown]
# ### 4.2) The value of each aggregation on each datetime for each attribute is available in a pandas dataframe format

# %%
aggregation_df = summarize.pandas_dataframe()
aggregation_df
# Out:
#    attribute aggregation   datetime     value
# 0       NDVI        mean 2017-01-01  0.863212
# 1       NDVI         std 2017-01-01  0.016954
# 2       NDVI        mean 2017-01-17  0.606783
# 3       NDVI         std 2017-01-17  0.164964
# 4       NDVI        mean 2017-02-02  0.828055
# ..       ...         ...        ...       ...
# 95       EVI         std 2017-12-19  0.114733
# 96       EVI        mean 2018-01-01  0.396667
# 97       EVI         std 2018-01-01  0.025366
# 98       EVI        mean 2018-01-17  0.439157
# 99       EVI         std 2018-01-17  0.032020
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 4.3) The user can plot the summarized timeseries

# %%
# Plot the selected aggregation chart for the selected attribute(s)
summarize.plot(
    attributes = ['NDVI','EVI'],
    aggregation = 'mean'
)

# %%
# Plot the mean+std/mean-std chart for the selected attribute
summarize.plot_mean_std(
    attribute='EVI'
)
